# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# might have to pip install -q transformers
from transformers import pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor, GradientBoostingRegressor
import random
import re

# %% [markdown]
# # Import Data

# %%
data = pd.read_csv('Recipe Reviews and User Feedback Dataset.csv')

# %% [markdown]
# # General Data Summary

# %%
n_rows = data.shape[0]
n_recipes = data["recipe_code"].nunique()
n_reviews = data["comment_id"].nunique()
print("Number of features: ", n_columns)
print("Number of reviews: ", n_reviews)
print("Number of recipes: ", n_recipes)
# Out:
# Number of features:  16
# Number of reviews:  18182
# Number of recipes:  100

# %%
total_thumbs = data.groupby('recipe_code').agg({'thumbs_up': 'sum', 'thumbs_down': 'sum', 'recipe_code': 'count'})
total_thumbs.columns = ['total_thumbs_up', 'total_thumbs_down', 'count']

# %%
total_thumbs['sentiment'] = 'positive'
total_thumbs.loc[total_thumbs['total_thumbs_up'] < total_thumbs['total_thumbs_down'], 'sentiment'] = 'negative'

# Count the number of recipes with positive and negative sentiment
sentiment_counts = total_thumbs['sentiment'].value_counts()

# Plotting
plt.bar(sentiment_counts.index, sentiment_counts.values, color=['green', 'red'])
plt.xlabel('Sentiment')
plt.ylabel('Number of Recipes')
plt.title('Number of Recipes with Positive and Negative Sentiment')
plt.show()

# %% [markdown]
# # Part 1: Sentiment Analysis of Reviews

# %%
sentiment_pipeline = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
x = sentiment_pipeline(data['text'][0])

# %%
x
# Out:
# [{'label': 'POSITIVE', 'score': 0.9997697472572327}]

# %%
x[0]['score']
# Out:
# 0.9997697472572327

# %% [markdown]
# # Question 1
# Do reviews with more positive scores recieve more thumbs up? Same with vice versa

# %%
sentiment_df = data
sentiment_df["sentiment_score"] = None

# %%
def remove_html_entity(input_string):
    input_string = str(input_string)
    result_string = input_string.replace("&#39;", "")
    result_string = result_string.replace("<h1>", "")
    result_string = result_string.replace("</h1>", "")
    result_string = result_string.replace("<span>", "")
    result_string = result_string.replace("</span>", "")
    result_string = result_string.replace("<li>", "")
    result_string = result_string.replace("</li>", "")
    result_string = result_string.replace("<i>", "")
    result_string = result_string.replace("</i>", "")
    result_string = result_string.replace("<h2>", "")
    result_string = result_string.replace("</h2>", "")
    result_string = result_string.replace("<ul>", "")
    result_string = result_string.replace("</ul>", "")
    result_string = result_string.replace("<b>", "")
    result_string = result_string.replace("</b>", "")
    result_string = result_string.replace("\xa0", "")
    

    return result_string

# %%
# Change the object to a list
texts = []
for t in range(len(sentiment_df['text'])):
    text = sentiment_df['text'][t]
    text = remove_html_entity(text)
    if str(text) != "nan":
        texts.append(text)
        if len(text) > 2000:
            text_1 = text[0:1500]
            text_2 = text[1500:]
            sentiment_1 = sentiment_pipeline(text_1)[0]['score']
            sentiment_2 = sentiment_pipeline(text_2)[0]['score']
            sentiment_df["sentiment_score"][t] = (sentiment_1  + sentiment_2)/2
        else:
            sentiment_df["sentiment_score"][t] = sentiment_pipeline(text)[0]['score']
    else:
        sentiment_df["sentiment_score"][t] = 0
# Out:
# /var/folders/3k/0s83074d3_93z_bq3nvj2n0r0000gn/T/ipykernel_21318/2769961053.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sentiment_df["sentiment_score"][t] = sentiment_pipeline(text)[0]['score']
# /var/folders/3k/0s83074d3_93z_bq3nvj2n0r0000gn/T/ipykernel_21318/2769961053.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sentiment_df["sentiment_score"][t] = 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <cell line: 3>()
#      13         sentiment_df["sentiment_score"][t] = (sentiment_1  + sentiment_2)/2
#      14     else:
# ---> 15         sentiment_df["sentiment_score"][t] = sentiment_pipeline(text)[0]['score']
#      16 else:
#      17     sentiment_df["sentiment_score"][t] = 0
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/pipelines/text_classification.py:156, in TextClassificationPipeline.__call__(self, inputs, **kwargs)
#     122 """
#     123 Classify the text(s) given as inputs.
#     124
#    (...)
#     153     If `top_k` is used, one such dictionary is returned per label.
#     154 """
#     155 inputs = (inputs,)
# --> 156 result = super().__call__(*inputs, **kwargs)
#     157 # TODO try and retrieve it in a nicer way from _sanitize_parameters.
#     158 _legacy = "top_k" not in kwargs
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/pipelines/base.py:1206, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1198     return next(
#    1199         iter(
#    1200             self.get_iterator(
#    (...)
#    1203         )
#    1204     )
#    1205 else:
# -> 1206     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/pipelines/base.py:1213, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1211 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1212     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1213     model_outputs = self.forward(model_inputs, **forward_params)
#    1214     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1215     return outputs
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/pipelines/base.py:1112, in Pipeline.forward(self, model_inputs, **forward_params)
#    1110     with inference_context():
#    1111         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1112         model_outputs = self._forward(model_inputs, **forward_params)
#    1113         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1114 else:
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/pipelines/text_classification.py:187, in TextClassificationPipeline._forward(self, model_inputs)
#     185 if "use_cache" in inspect.signature(model_forward).parameters.keys():
#     186     model_inputs["use_cache"] = False
# --> 187 return self.model(**model_inputs)
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/models/distilbert/modeling_distilbert.py:1002, in DistilBertForSequenceClassification.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     994 r"""
#     995 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#     996     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#     997     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#     998     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#     999 """
#    1000 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1002 distilbert_output = self.distilbert(
#    1003     input_ids=input_ids,
#    1004     attention_mask=attention_mask,
#    1005     head_mask=head_mask,
#    1006     inputs_embeds=inputs_embeds,
#    1007     output_attentions=output_attentions,
#    1008     output_hidden_states=output_hidden_states,
#    1009     return_dict=return_dict,
#    1010 )
#    1011 hidden_state = distilbert_output[0]  # (bs, seq_len, dim)
#    1012 pooled_output = hidden_state[:, 0]  # (bs, dim)
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/models/distilbert/modeling_distilbert.py:822, in DistilBertModel.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     819     if attention_mask is None:
#     820         attention_mask = torch.ones(input_shape, device=device)  # (bs, seq_length)
# --> 822 return self.transformer(
#     823     x=embeddings,
#     824     attn_mask=attention_mask,
#     825     head_mask=head_mask,
#     826     output_attentions=output_attentions,
#     827     output_hidden_states=output_hidden_states,
#     828     return_dict=return_dict,
#     829 )
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/models/distilbert/modeling_distilbert.py:587, in Transformer.forward(self, x, attn_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     579     layer_outputs = self._gradient_checkpointing_func(
#     580         layer_module.__call__,
#     581         hidden_state,
#    (...)
#     584         output_attentions,
#     585     )
#     586 else:
# --> 587     layer_outputs = layer_module(
#     588         hidden_state,
#     589         attn_mask,
#     590         head_mask[i],
#     591         output_attentions,
#     592     )
#     594 hidden_state = layer_outputs[-1]
#     596 if output_attentions:
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/models/distilbert/modeling_distilbert.py:531, in TransformerBlock.forward(self, x, attn_mask, head_mask, output_attentions)
#     528 sa_output = self.sa_layer_norm(sa_output + x)  # (bs, seq_length, dim)
#     530 # Feed Forward Network
# --> 531 ffn_output = self.ffn(sa_output)  # (bs, seq_length, dim)
#     532 ffn_output: torch.Tensor = self.output_layer_norm(ffn_output + sa_output)  # (bs, seq_length, dim)
#     534 output = (ffn_output,)
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/models/distilbert/modeling_distilbert.py:466, in FFN.forward(self, input)
#     465 def forward(self, input: torch.Tensor) -> torch.Tensor:
# --> 466     return apply_chunking_to_forward(self.ff_chunk, self.chunk_size_feed_forward, self.seq_len_dim, input)
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/pytorch_utils.py:237, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     234     # concatenate output at same dimension
#     235     return torch.cat(output_chunks, dim=chunk_dim)
# --> 237 return forward_fn(*input_tensors)
#
# File ~/miniconda3/lib/python3.9/site-packages/transformers/models/distilbert/modeling_distilbert.py:471, in FFN.ff_chunk(self, input)
#     469 x = self.lin1(input)
#     470 x = self.activation(x)
# --> 471 x = self.lin2(x)
#     472 x = self.dropout(x)
#     473 return x
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
sentiment_df.to_csv('sentiment_df.csv', index=False)

# %% [markdown]
# # Question 2 - Reviews Overtime
# ### How do the reviews change overtime if at all?
# - Use timestamps to make “timeline” of review sentiments overtime
# - Use the running average of the ratings to look for deviations from average.

# %% [markdown]
# ## Step 1: One recipe
# Get all review for one recipie and track sentiments & thumbs up over time

# %%
random_idx = random.randint(1, len(data))
recipie_code = data['recipe_code'][random_idx]

# %%
recipie_reviews = data[data['recipe_code'] == recipie_code]
# sort by time
recipie_reviews = recipie_reviews.sort_values(by='created_at')

# %%
# Plotting the bar plot
plt.figure(figsize=(10, 6))  # Adjust size as needed
plt.bar(range(len(recipie_reviews)), recipie_reviews['thumbs_up'], align='edge')

# Adding labels and title
plt.xlabel('Index')
plt.ylabel('Thumbs Up')
plt.title('Thumbs Up Count for Sorted Result')
plt.xticks(range(len(recipie_reviews)), range(1, len(recipie_reviews) + 1))

# Show plot
plt.tight_layout()
plt.show()

# %%
# Plotting the bar plot
plt.figure(figsize=(10, 6))  # Adjust size as needed
plt.bar(range(len(recipie_reviews)), recipie_reviews['best_score'], align='edge')

# Adding labels and title
plt.xlabel('Index')
plt.ylabel('Best Score')
plt.title('Best Score for Sorted Result')
plt.xticks(range(len(recipie_reviews)), range(1, len(recipie_reviews) + 1))

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sentiment

# %%
random_idx = random.randint(1, len(sentiment_df))
recipie_code = sentiment_df['recipe_code'][random_idx]
recipie_reviews = sentiment_df[sentiment_df['recipe_code'] == recipie_code]
recipie_reviews = recipie_reviews.sort_values(by='created_at')

# %%
# Plotting the bar plot
plt.figure(figsize=(10, 6))  # Adjust size as needed
plt.bar(range(len(recipie_reviews)), recipie_reviews['sentiment_score'])

# Adding labels and title
plt.xlabel('Index')
plt.ylabel('Sentiment Score')
plt.title('Sentiment Score for Sorted Result')
#plt.xticks(range(len(recipie_reviews)), range(1, len(recipie_reviews) + 1))

# Show plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 3>()
#       1 # Plotting the bar plot
#       2 plt.figure(figsize=(10, 6))  # Adjust size as needed
# ----> 3 plt.bar(range(len(recipie_reviews)), recipie_reviews['sentiment_score'])
#       5 # Adding labels and title
#       6 plt.xlabel('Index')
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2754, in bar(x, height, width, bottom, align, data, **kwargs)
#    2743 @_copy_docstring_and_deprecators(Axes.bar)
#    2744 def bar(
#    2745     x: float | ArrayLike,
#    (...)
#    2752     **kwargs,
#    2753 ) -> BarContainer:
# -> 2754     return gca().bar(
#    2755         x,
#    2756         height,
#    2757         width=width,
#    2758         bottom=bottom,
#    2759         align=align,
#    2760         **({"data": data} if data is not None else {}),
#    2761         **kwargs,
#    2762     )
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:2523, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2520 args = zip(left, bottom, width, height, color, edgecolor, linewidth,
#    2521            hatch, patch_labels)
#    2522 for l, b, w, h, c, e, lw, htch, lbl in args:
# -> 2523     r = mpatches.Rectangle(
#    2524         xy=(l, b), width=w, height=h,
#    2525         facecolor=c,
#    2526         edgecolor=e,
#    2527         linewidth=lw,
#    2528         label=lbl,
#    2529         hatch=htch,
#    2530         )
#    2531     r._internal_update(kwargs)
#    2532     r.get_path()._interpolation_steps = 100
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/patches.py:732, in Rectangle.__init__(self, xy, width, height, angle, rotation_point, **kwargs)
#     725 # Required for RectangleSelector with axes aspect ratio != 1
#     726 # The patch is defined in data coordinates and when changing the
#     727 # selector with square modifier and not in data coordinates, we need
#     728 # to correct for the aspect ratio difference between the data and
#     729 # display coordinate systems. Its value is typically provide by
#     730 # Axes._get_aspect_ratio()
#     731 self._aspect_ratio_correction = 1.0
# --> 732 self._convert_units()
#
# File ~/miniconda3/lib/python3.9/site-packages/matplotlib/patches.py:743, in Rectangle._convert_units(self)
#     741 y0 = self.convert_yunits(self._y0)
#     742 x1 = self.convert_xunits(self._x0 + self._width)
# --> 743 y1 = self.convert_yunits(self._y0 + self._height)
#     744 return x0, y0, x1, y1
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %% [markdown]
# looks like sentiments DO NOT change overtime but "best score" does! There are definitley some deviations though which is pretty interesting!

# %% [markdown]
# # Question 3 - Length of Reviews vs. Intearctions
# ### Does the length of the review indicate anything about it's sentiment?
# - Calculate average length of reviews for each recipe.
# - Calculate average total interactions for reviews of each recipe.
# - Calculate average reply count for reviews of each recipe.
# - Calculate average thumbs up for reviews of each recipe.
# - Calculate average thumbs down for reviews of each recipe.

# %% [markdown]
# ## 1) Calculate average length, total interactions, replies, thumbs up & thumbs down of reviews for each recipe

# %%
avg_length = data.groupby('recipe_code').apply(lambda x: pd.Series({
                    'avg_length': x['text'].str.len().mean(),
                    'avg_created_at': x['created_at'].mean(),
                    'num_reviews': x.shape[0],
                    'avg_replies': x['reply_count'].mean(),
                    'avg_thumbs_up': x['thumbs_up'].mean(),
                    'avg_thumbs_down': x['thumbs_down'].mean(),
                    'avg_score': x['best_score'].mean(),
                    'avg_total_interactions': x['reply_count'].mean() + x['thumbs_up'].mean() + x['thumbs_down'].mean()
                    })).reset_index()
avg_length.tail()
# Out:
#     recipe_code  avg_length  avg_created_at  num_reviews  avg_replies  \
# 95        74724  191.204082    1.623096e+09        147.0     0.000000
# 96        82745  252.899160    1.625245e+09        119.0     0.033613
# 97       100276  157.195122    1.623248e+09        164.0     0.012195
# 98       141947  241.719298    1.624951e+09        114.0     0.008772
# 99       191775  243.008929    1.624278e+09        112.0     0.000000
#
#     avg_thumbs_up  avg_thumbs_down   avg_score  avg_total_interactions
# 95       0.163265         0.061224  118.734694                0.224490
# 96       1.554622         0.789916  208.865546                2.378151
# 97       1.365854         0.457317  161.817073                1.835366
# 98       3.114035         1.692982  219.684211                4.815789
# 99       1.258929         0.535714  188.821429                1.794643

# %% [markdown]
# ## 2) Perform Linear Regression on the number of reviews, average replies, average thumbs up & thumbs down with average review length as the target.

# %%
X = avg_length[['num_reviews', 'avg_replies', 'avg_thumbs_up', 'avg_thumbs_down']]
y = avg_length['avg_length']

al_Model = LinearRegression().fit(X,y)

print("Coefficients:", al_Model.coef_)
print("Intercept:", al_Model.intercept_)
# Out:
# Coefficients: [ 2.19913019e-02  8.26748859e+01  8.21858724e+00 -1.01612182e+00]
# Intercept: 188.94427270541212

# %% [markdown]
# ## 3) Plot Average Length vs. Interaction Metrics

# %% [markdown]
# ## Data Cleaning: Sort avg_length dataframe by increasing Average Length for consistency & visual analysis

# %%
sorted_avg_length = avg_length.sort_values(by='avg_length')

# %% [markdown]
# ### a. Plot Average Length vs. Number of reviews

# %%
# Plot Interaction Variables
plt.plot(sorted_avg_length['avg_length'], sorted_avg_length['avg_replies'], label='Average Reply Count')

# Adding labels and title
plt.xlabel('Average Text Length')
plt.ylabel('Average Reply Count')
plt.title('Average Text Length vs Avg Reply Count')
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# ### b. Plot Average Length vs. Number of Reviews

# %%
plt.plot(sorted_avg_length['avg_length'], sorted_avg_length['num_reviews'], label='Number of Reviews')

# Adding labels and title
plt.xlabel('Average Text Length')
plt.ylabel('Value')
plt.title('Average Text Length vs Number of Reviews')
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# ### c. Plot Average Length vs. Average Thumbs Up & Thumbs Down

# %%
plt.plot(sorted_avg_length['avg_length'], sorted_avg_length['avg_thumbs_up'], label='Average Thumbs Up')
plt.plot(sorted_avg_length['avg_length'], sorted_avg_length['avg_thumbs_down'], label='Average Thumbs Down')

# Adding labels and title
plt.xlabel('Average Text Length')
plt.ylabel('Value')
plt.title('Average Text Length vs Thumbs Up & Thumbs Down')
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# ### d. Plot Average Length vs. Average Total Interactions

# %%
plt.plot(sorted_avg_length['avg_length'], sorted_avg_length['avg_total_interactions'], label='Average Total Interactions')

# Adding labels and title
plt.xlabel('Average Text Length')
plt.ylabel('Average Total Interactions')
plt.title('Average Text Length vs Average Total Interactions')
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# ### e. Plot Avg Total Interactions vs. Total Reply Count

# %%
sorted_created_at = avg_length.sort_values(by='avg_created_at')
plt.plot(sorted_created_at['avg_created_at'], sorted_created_at['avg_thumbs_up'], label='Average Thumbs Up')
plt.plot(sorted_created_at['avg_created_at'], sorted_created_at['avg_thumbs_down'], label='Average Thumbs Down')

# Adding labels and title
plt.xlabel('Average Created At')
plt.ylabel('Thumbs')
plt.title('Average Created At vs Thumbs Up & Thumbs Down')
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# ## Correlation Matrix for Avg Variables

# %%
corr_matrix = avg_length.corr()
format_corr_matrix = corr_matrix.style.background_gradient(cmap='coolwarm', axis = None)
new_corr_matrix = format_corr_matrix.format(precision=2)
new_corr_matrix
# Out:
# <style type="text/css">
# #T_f376c_row0_col0, #T_f376c_row1_col1, #T_f376c_row2_col2, #T_f376c_row3_col3, #T_f376c_row4_col4, #T_f376c_row5_col5, #T_f376c_row6_col6, #T_f376c_row7_col7, #T_f376c_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f376c_row0_col1, #T_f376c_row1_col0 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_f376c_row0_col2, #T_f376c_row0_col5, #T_f376c_row2_col0, #T_f376c_row5_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_f376c_row0_col3, #T_f376c_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f376c_row0_col4, #T_f376c_row3_col7, #T_f376c_row4_col0, #T_f376c_row7_col3 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_f376c_row0_col6, #T_f376c_row6_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_f376c_row0_col7, #T_f376c_row7_col0 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_f376c_row0_col8, #T_f376c_row8_col0 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_f376c_row1_col2, #T_f376c_row2_col1 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_f376c_row1_col3, #T_f376c_row3_col1 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_f376c_row1_col4, #T_f376c_row4_col1 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_f376c_row1_col5, #T_f376c_row1_col7, #T_f376c_row5_col1, #T_f376c_row7_col1 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_f376c_row1_col6, #T_f376c_row6_col1 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_f376c_row1_col8, #T_f376c_row8_col1 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_f376c_row2_col3, #T_f376c_row3_col2 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_f376c_row2_col4, #T_f376c_row4_col2 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_f376c_row2_col5, #T_f376c_row5_col2 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_f376c_row2_col6, #T_f376c_row6_col2 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_f376c_row2_col7, #T_f376c_row7_col2 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_f376c_row2_col8, #T_f376c_row6_col7, #T_f376c_row7_col6, #T_f376c_row8_col2 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_f376c_row3_col4, #T_f376c_row4_col3 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_f376c_row3_col5, #T_f376c_row5_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_f376c_row3_col6, #T_f376c_row6_col3 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_f376c_row3_col8, #T_f376c_row8_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_f376c_row4_col5, #T_f376c_row5_col4 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_f376c_row4_col6, #T_f376c_row6_col4 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_f376c_row4_col7, #T_f376c_row7_col4 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_f376c_row4_col8, #T_f376c_row8_col4 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_f376c_row5_col6, #T_f376c_row6_col5 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_f376c_row5_col7, #T_f376c_row7_col5 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_f376c_row5_col8, #T_f376c_row8_col5 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_f376c_row6_col8, #T_f376c_row8_col6 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_f376c_row7_col8, #T_f376c_row8_col7 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f376c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f376c_level0_col0" class="col_heading level0 col0" >recipe_code</th>
#       <th id="T_f376c_level0_col1" class="col_heading level0 col1" >avg_length</th>
#       <th id="T_f376c_level0_col2" class="col_heading level0 col2" >avg_created_at</th>
#       <th id="T_f376c_level0_col3" class="col_heading level0 col3" >num_reviews</th>
#       <th id="T_f376c_level0_col4" class="col_heading level0 col4" >avg_replies</th>
#       <th id="T_f376c_level0_col5" class="col_heading level0 col5" >avg_thumbs_up</th>
#       <th id="T_f376c_level0_col6" class="col_heading level0 col6" >avg_thumbs_down</th>
#       <th id="T_f376c_level0_col7" class="col_heading level0 col7" >avg_score</th>
#       <th id="T_f376c_level0_col8" class="col_heading level0 col8" >avg_total_interactions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f376c_level0_row0" class="row_heading level0 row0" >recipe_code</th>
#       <td id="T_f376c_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_f376c_row0_col1" class="data row0 col1" >0.07</td>
#       <td id="T_f376c_row0_col2" class="data row0 col2" >0.06</td>
#       <td id="T_f376c_row0_col3" class="data row0 col3" >-0.16</td>
#       <td id="T_f376c_row0_col4" class="data row0 col4" >-0.15</td>
#       <td id="T_f376c_row0_col5" class="data row0 col5" >0.06</td>
#       <td id="T_f376c_row0_col6" class="data row0 col6" >0.03</td>
#       <td id="T_f376c_row0_col7" class="data row0 col7" >0.12</td>
#       <td id="T_f376c_row0_col8" class="data row0 col8" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_f376c_level0_row1" class="row_heading level0 row1" >avg_length</th>
#       <td id="T_f376c_row1_col0" class="data row1 col0" >0.07</td>
#       <td id="T_f376c_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_f376c_row1_col2" class="data row1 col2" >0.31</td>
#       <td id="T_f376c_row1_col3" class="data row1 col3" >0.05</td>
#       <td id="T_f376c_row1_col4" class="data row1 col4" >0.19</td>
#       <td id="T_f376c_row1_col5" class="data row1 col5" >0.27</td>
#       <td id="T_f376c_row1_col6" class="data row1 col6" >0.24</td>
#       <td id="T_f376c_row1_col7" class="data row1 col7" >0.27</td>
#       <td id="T_f376c_row1_col8" class="data row1 col8" >0.27</td>
#     </tr>
#     <tr>
#       <th id="T_f376c_level0_row2" class="row_heading level0 row2" >avg_created_at</th>
#       <td id="T_f376c_row2_col0" class="data row2 col0" >0.06</td>
#       <td id="T_f376c_row2_col1" class="data row2 col1" >0.31</td>
#       <td id="T_f376c_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_f376c_row2_col3" class="data row2 col3" >0.01</td>
#       <td id="T_f376c_row2_col4" class="data row2 col4" >0.51</td>
#       <td id="T_f376c_row2_col5" class="data row2 col5" >0.78</td>
#       <td id="T_f376c_row2_col6" class="data row2 col6" >0.73</td>
#       <td id="T_f376c_row2_col7" class="data row2 col7" >0.86</td>
#       <td id="T_f376c_row2_col8" class="data row2 col8" >0.79</td>
#     </tr>
#     <tr>
#       <th id="T_f376c_level0_row3" class="row_heading level0 row3" >num_reviews</th>
#       <td id="T_f376c_row3_col0" class="data row3 col0" >-0.16</td>
#       <td id="T_f376c_row3_col1" class="data row3 col1" >0.05</td>
#       <td id="T_f376c_row3_col2" class="data row3 col2" >0.01</td>
#       <td id="T_f376c_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_f376c_row3_col4" class="data row3 col4" >-0.02</td>
#       <td id="T_f376c_row3_col5" class="data row3 col5" >-0.10</td>
#       <td id="T_f376c_row3_col6" class="data row3 col6" >-0.12</td>
#       <td id="T_f376c_row3_col7" class="data row3 col7" >-0.15</td>
#       <td id="T_f376c_row3_col8" class="data row3 col8" >-0.11</td>
#     </tr>
#     <tr>
#       <th id="T_f376c_level0_row4" class="row_heading level0 row4" >avg_replies</th>
#       <td id="T_f376c_row4_col0" class="data row4 col0" >-0.15</td>
#       <td id="T_f376c_row4_col1" class="data row4 col1" >0.19</td>
#       <td id="T_f376c_row4_col2" class="data row4 col2" >0.51</td>
#       <td id="T_f376c_row4_col3" class="data row4 col3" >-0.02</td>
#       <td id="T_f376c_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_f376c_row4_col5" class="data row4 col5" >0.55</td>
#       <td id="T_f376c_row4_col6" class="data row4 col6" >0.56</td>
#       <td id="T_f376c_row4_col7" class="data row4 col7" >0.53</td>
#       <td id="T_f376c_row4_col8" class="data row4 col8" >0.58</td>
#     </tr>
#     <tr>
#       <th id="T_f376c_level0_row5" class="row_heading level0 row5" >avg_thumbs_up</th>
#       <td id="T_f376c_row5_col0" class="data row5 col0" >0.06</td>
#       <td id="T_f376c_row5_col1" class="data row5 col1" >0.27</td>
#       <td id="T_f376c_r

# %% [markdown]
# # Question 4 - User Reputation vs. Sentiment
# ### Does the user reputation indicate anything about it's sentiment?
# - Calculate average user reputation of reviews for each recipe.
# - Calculate average sentiment for reviews of each recipe.
# - Calculate sentiment of recipe title?

# %% [markdown]
# # Part 2: Predicting Review Score using ML
# ### What features are most important to the review score / order of appearance on recipe comments?
# - Models: Linear Regression, Ridge Regression, LASSO, Regression Tree, Bagging, Random Forest, Boosted Trees, Neural Network
# - Features (normalize): user_reputation, created_at, reply_count, thumbs_up, thumbs_down, stars, text_length
# - Target: best_score

# %% [markdown]
# ## A. Clean Data
# ### 1. Remove unnecessary variables

# %%
data_ML_raw = data.drop(['Unnamed: 0', 'recipe_number', 'user_id', 'user_name'], axis = 1)
data_ML_raw.head()
# Out:
#    recipe_code         recipe_name  \
# 0        14299  Creamy White Chili
# 1        14299  Creamy White Chili
# 2        14299  Creamy White Chili
# 3        14299  Creamy White Chili
# 4        14299  Creamy White Chili
#
#                                         comment_id  user_reputation  \
# 0  sp_aUSaElGf_14299_c_2G3aneMRgRMZwXqIHmSdXSG1hEM                1
# 1  sp_aUSaElGf_14299_c_2FsPC83HtzCsQAtOxlbL6RcaPbY               50
# 2  sp_aUSaElGf_14299_c_2FPrSGyTv7PQkZq37j92r9mYGkP               10
# 3  sp_aUSaElGf_14299_c_2DzdSIgV9qNiuBaLoZ7JQaartoC                1
# 4  sp_aUSaElGf_14299_c_2DtZJuRQYeTFwXBoZRfRhBPEXjI               10
#
#    created_at  reply_count  thumbs_up  thumbs_down  stars  best_score  \
# 0  1665619889            0          0            0      5         527
# 1  1665277687            0          7            0      5         724
# 2  1664404557            0          3            0      5         710
# 3  1661787808            2          2            0      0         581
# 4  1664913823            1          7            0      0         820
#
#                                                 text sentiment_score
# 0  I tweaked it a little, removed onions because ...            None
# 1  Bush used to have a white chili bean and it ma...            None
# 2  I have a very complicated white chicken chili ...            None
# 3  In your introduction, you mentioned cream chee...            None
# 4  Wonderful! I made this for a &#34;Chili/Stew&#...            None

# %% [markdown]
# ### 2. Sort data by recipe_code (ascending) & best_score (descending)

# %%
# sort dataframe by recipe_code & best_score
data_ML_sorted = data_ML_raw.sort_values(['recipe_code', 'best_score'], ascending = [True, False])
data_ML_sorted.head()
# Out:
#       recipe_code    recipe_name  \
# 7761          386  Hot Milk Cake
# 7757          386  Hot Milk Cake
# 7759          386  Hot Milk Cake
# 7758          386  Hot Milk Cake
# 7755          386  Hot Milk Cake
#
#                                          comment_id  user_reputation  \
# 7761  sp_aUSaElGf_386_c_1ybGEs91lVCmxcU68a6xDxIgq5t                1
# 7757  sp_aUSaElGf_386_c_2Ddrc8KBpq9jZ2OUZkjPLEz1nBB                1
# 7759  sp_aUSaElGf_386_c_26z31AlGvDdp2FDsBiOYdcaDamn                1
# 7758  sp_aUSaElGf_386_c_28DPJerhU4Tz1Urg7URYCvbomRM               10
# 7755  sp_aUSaElGf_386_c_2FH8FfVpgwDPx2PQuG5ASe5g9IS                1
#
#       created_at  reply_count  thumbs_up  thumbs_down  stars  best_score  \
# 7761  1632512765            0         41            2      0         922
# 7757  1661039878            0         10            0      4         851
# 7759  1648412369            0         22            3      5         841
# 7758  1650748112            0          7            0      5         835
# 7755  1664137547            0         13            0      4         834
#
#                                                    text sentiment_score
# 7761  This is very similar to the recipe I grew up w...            None
# 7757  My husband loves this recipe!  The only thing ...            None
# 7759  Wonderfully flavored cake. I followed the advi...            None
# 7758  My mom gave this recipe to me years ago, and i...            None
# 7755  My grandmother made this and when it came out ...            None

# %% [markdown]
# ### 3. Count character length of "recipe_name" and "text" columns

# %%
# create new dataframe for recipe_name length and text length
text_lengths = data_ML_sorted.apply(lambda row: [len(str(row['recipe_name'])), len(str(row['text']))], axis = 1, result_type = 'expand')
text_lengths.columns = ['recipe_name_length', 'review_length']

# append new dataframe to existing data_ML
data_ML = pd.concat([data_ML_sorted, text_lengths], axis = 1, join = 'outer')
data_ML.head()
# Out:
#       recipe_code    recipe_name  \
# 7761          386  Hot Milk Cake
# 7757          386  Hot Milk Cake
# 7759          386  Hot Milk Cake
# 7758          386  Hot Milk Cake
# 7755          386  Hot Milk Cake
#
#                                          comment_id  user_reputation  \
# 7761  sp_aUSaElGf_386_c_1ybGEs91lVCmxcU68a6xDxIgq5t                1
# 7757  sp_aUSaElGf_386_c_2Ddrc8KBpq9jZ2OUZkjPLEz1nBB                1
# 7759  sp_aUSaElGf_386_c_26z31AlGvDdp2FDsBiOYdcaDamn                1
# 7758  sp_aUSaElGf_386_c_28DPJerhU4Tz1Urg7URYCvbomRM               10
# 7755  sp_aUSaElGf_386_c_2FH8FfVpgwDPx2PQuG5ASe5g9IS                1
#
#       created_at  reply_count  thumbs_up  thumbs_down  stars  best_score  \
# 7761  1632512765            0         41            2      0         922
# 7757  1661039878            0         10            0      4         851
# 7759  1648412369            0         22            3      5         841
# 7758  1650748112            0          7            0      5         835
# 7755  1664137547            0         13            0      4         834
#
#                                                    text sentiment_score  \
# 7761  This is very similar to the recipe I grew up w...            None
# 7757  My husband loves this recipe!  The only thing ...            None
# 7759  Wonderfully flavored cake. I followed the advi...            None
# 7758  My mom gave this recipe to me years ago, and i...            None
# 7755  My grandmother made this and when it came out ...            None
#
#       recipe_name_length  review_length
# 7761                  13            287
# 7757                  13            134
# 7759                  13            191
# 7758                  13            205
# 7755                  13            132

# %% [markdown]
# ### 4. Standardize / Normalize variables

# %% [markdown]
# #### a) Visualize each variable's distribution

# %%
data_ML
data_ML.hist(figsize =(15,9))
plt.show()
# Out:
# <style type="text/css">
# #T_11b10_row0_col0, #T_11b10_row1_col1, #T_11b10_row2_col2, #T_11b10_row3_col3, #T_11b10_row4_col4, #T_11b10_row5_col5, #T_11b10_row6_col6, #T_11b10_row7_col7, #T_11b10_row8_col8, #T_11b10_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_11b10_row0_col1, #T_11b10_row1_col0, #T_11b10_row1_col6, #T_11b10_row6_col1 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_11b10_row0_col2, #T_11b10_row0_col5, #T_11b10_row0_col9, #T_11b10_row2_col0, #T_11b10_row2_col8, #T_11b10_row3_col8, #T_11b10_row5_col0, #T_11b10_row7_col8, #T_11b10_row8_col2, #T_11b10_row8_col3, #T_11b10_row8_col7, #T_11b10_row9_col0 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_11b10_row0_col3, #T_11b10_row3_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_11b10_row0_col4, #T_11b10_row1_col3, #T_11b10_row3_col1, #T_11b10_row4_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_11b10_row0_col6, #T_11b10_row6_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_11b10_row0_col7, #T_11b10_row1_col5, #T_11b10_row2_col9, #T_11b10_row5_col1, #T_11b10_row7_col0, #T_11b10_row9_col2 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_11b10_row0_col8, #T_11b10_row5_col7, #T_11b10_row7_col5, #T_11b10_row8_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_11b10_row1_col2, #T_11b10_row2_col1 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_11b10_row1_col4, #T_11b10_row4_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_11b10_row1_col7, #T_11b10_row7_col1 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_11b10_row1_col8, #T_11b10_row6_col8, #T_11b10_row8_col1, #T_11b10_row8_col6 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_11b10_row1_col9, #T_11b10_row8_col9, #T_11b10_row9_col1, #T_11b10_row9_col8 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_11b10_row2_col3, #T_11b10_row3_col2 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_11b10_row2_col4, #T_11b10_row4_col2 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_11b10_row2_col5, #T_11b10_row5_col2 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_11b10_row2_col6, #T_11b10_row6_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_11b10_row2_col7, #T_11b10_row4_col7, #T_11b10_row7_col2, #T_11b10_row7_col4 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_11b10_row3_col4, #T_11b10_row4_col3 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_11b10_row3_col5, #T_11b10_row5_col3 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_11b10_row3_col6, #T_11b10_row6_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_11b10_row3_col7, #T_11b10_row7_col3 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_11b10_row3_col9, #T_11b10_row9_col3 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_11b10_row4_col5, #T_11b10_row5_col4 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_11b10_row4_col6, #T_11b10_row6_col4 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_11b10_row4_col8, #T_11b10_row8_col4 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_11b10_row4_col9, #T_11b10_row9_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_11b10_row5_col6, #T_11b10_row6_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_11b10_row5_col8, #T_11b10_row8_col5 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_11b10_row5_col9, #T_11b10_row9_col5 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_11b10_row6_col7, #T_11b10_row7_col6 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_11b10_row6_col9, #T_11b10_row9_col6 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_11b10_row7_col9, #T_11b10_row9_col7 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_11b10">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11b10_level0_col0" class="col_heading level0 col0" >recipe_code</th>
#       <th id="T_11b10_level0_col1" class="col_heading level0 col1" >user_reputation</th>
#       <th id="T_11b10_level0_col2" class="col_heading level0 col2" >created_at</th>
#       <th id="T_11b10_level0_col3" class="col_heading level0 col3" >reply_count</th>
#       <th id="T_11b10_level0_col4" class="col_heading level0 col4" >thumbs_up</th>
#       <th id="T_11b10_level0_col5" class="col_heading level0 col5" >thumbs_down</th>
#       <th id="T_11b10_level0_col6" class="col_heading level0 col6" >stars</th>
#       <th id="T_11b10_level0_col7" class="col_heading level0 col7" >best_score</th>
#       <th id="T_11b10_level0_col8" class="col_heading level0 col8" >recipe_name_length</th>
#       <th id="T_11b10_level0_col9" class="col_heading level0 col9" >review_length</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11b10_level0_row0" class="row_heading level0 row0" >recipe_code</th>
#       <td id="T_11b10_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_11b10_row0_col1" class="data row0 col1" >0.02</td>
#       <td id="T_11b10_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_11b10_row0_col3" class="data row0 col3" >-0.02</td>
#       <td id="T_11b10_row0_col4" class="data row0 col4" >0.01</td>
#       <td id="T_11b10_row0_col5" class="data row0 col5" >0.00</td>
#       <td id="T_11b10_row0_col6" class="data row0 col6" >-0.02</td>
#       <td id="T_11b10_row0_col7" class="data row0 col7" >0.02</td>
#       <td id="T_11b10_row0_col8" class="data row0 col8" >0.21</td>
#       <td id="T_11b10_row0_col9" class="data row0 col9" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_11b10_level0_row1" class="row_heading level0 row1" >user_reputation</th>
#       <td id="T_11b10_row1_col0" class="data row1 col0" >0.02</td>
#       <td id="T_11b10_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_11b10_row1_col2" class="data row1 col2" >0.19</td>
#       <td id="T_11b10_row1_col3" class="data row1 col3" >0.01</td>
#       <td id="T_11b10_row1_col4" class="data row1 col4" >0.06</td>
#       <td id="T_11b10_row1_col5" class="data row1 col5" >0.02</td>
#       <td id="T_11b10_row1_col6" class="data row1 col6" >0.02</td>
#       <td id="T_11b10_row1_col7" class="data row1 col7" >0.14</td>
#       <td id="T_11b10_row1_col8" class="data row1 col8" >-0.00</td>
#       <td id="T_11b10_row1_col9" class="data row1 col9" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_11b10_level0_row2" class="row_heading level0 row2" >created_at</th>
#       <td id="T_11b10_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_11b10_row2_col1" class="data row2 col1" >0.19</td>
#       <td id="T_11b10_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_11b10_row2_col3" class="data row2 col3" >0.16</td>
#       <td id="T_11b10_row2_col4" class="data row2 col4" >0.31</td>
#       <td id="T_11b10_row2_col5" class="data row2 col5" >0.18</td>
#       <td id="T_11b10_row2_col6" class="data row2 col6" >-0.06</td>
#       <td id="T_11b10_row2_col7" class="data row2 col7" >0.68</td>
#       <td id="T_11b10_row2_col8" class="data row2 col8" >0.00</td>
#       <td id="T_11b10_row2_col9" class="data row2 col9" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_11b10_level0_row3" class="row_heading level0 row3" >reply_count</th>
#       <td id="T_11b10_row3_col0" class="data row3 col0" >-0.02</td>
#       <td id="T_11b10_row3_col1" class="data row3 col1" >0.01</td>
#       <td id="T_11b10_row3_col2" class="data row3 col2" >0.16</td>
#       <td id="T_11b10_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_11b10_row3_col4" class="data row3 col4" >0.21</td>
#       <td id="T_11b10_row3_col5" class="data row3 col5" >0.33</td>
#       <td id="T_11b10_row3_col6" class="data row3 col6" >-0.12</td>
#       <td id="T_11b10_row3_col7" class="data row3 col7" >0.20</td>
#       <td id="T_11b10_row3_col8" class="data row3 col8" >0.00</td>
#       <td id="T_11b10_row3_col9" class="data row3 col9" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_11b10_level0_row4" class="row_heading level0 row4" >thumbs_up</th>
#       <td id="T_11b10_row4_col0" class="data row4 col0" >0.01</td>
#       <td id="T_11b10_row4_col1" class="data row4 col1" >0.06</td>
#       <td id="T_11

# %% [markdown]
# #### b) Standardize recipe_name_length & Normalize all others

# %%
# identify column to standardize & column to normalize
col_standardize = 'recipe_name_length'
col_normalize = ['user_reputation', 'created_at', 'reply_count', 'thumbs_up', 'thumbs_down', 'stars','best_score', 'review_length']

# initialize scalers
standard_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()

# transform variables
data_ML[col_standardize] = standard_scaler.fit_transform(data_ML[[col_standardize]])
data_ML[col_normalize] = minmax_scaler.fit_transform(data_ML[col_normalize])
data_ML.head()
# Out:
#       recipe_code    recipe_name  \
# 7761  386          Hot Milk Cake
# 7757  386          Hot Milk Cake
# 7759  386          Hot Milk Cake
# 7758  386          Hot Milk Cake
# 7755  386          Hot Milk Cake
#
#                                          comment_id  user_reputation  \
# 7761  sp_aUSaElGf_386_c_1ybGEs91lVCmxcU68a6xDxIgq5t  0.001923
# 7757  sp_aUSaElGf_386_c_2Ddrc8KBpq9jZ2OUZkjPLEz1nBB  0.001923
# 7759  sp_aUSaElGf_386_c_26z31AlGvDdp2FDsBiOYdcaDamn  0.001923
# 7758  sp_aUSaElGf_386_c_28DPJerhU4Tz1Urg7URYCvbomRM  0.019231
# 7755  sp_aUSaElGf_386_c_2FH8FfVpgwDPx2PQuG5ASe5g9IS  0.001923
#
#       created_at  reply_count  thumbs_up  thumbs_down  stars  best_score  \
# 7761  0.369446    0.0          0.386792   0.015873     0.0    0.974630
# 7757  0.910544    0.0          0.094340   0.000000     0.8    0.899577
# 7759  0.671027    0.0          0.207547   0.023810     1.0    0.889006
# 7758  0.715331    0.0          0.066038   0.000000     1.0    0.882664
# 7755  0.969301    0.0          0.122642   0.000000     0.8    0.881607
#
#                                                                                                                                                                                                                                                                                                  text  \
# 7761  This is very similar to the recipe I grew up with.  We waited until the butter and hot milk were added to the batter before putting in the vanilla---vanilla loses some of its&#39; flavor under direct heat like hot milk, so you&#39;ll get a better vanilla flavor if you add it at the end.
# 7757  My husband loves this recipe!  The only thing I find is I have to bake much longer than the 35 minutes, sometimes an extra 20 minutes.
# 7759  Wonderfully flavored cake. I followed the advice of one reviewer by adding the vanilla after I added the hot milk and butter. I baked it for 35 minutes and dusted the top with powdered sugar.
# 7758  My mom gave this recipe to me years ago, and it was perfect for strawberry shortcake.  It transported well and held up well with the addition of the strawberry sauce. Easy to make, and everyone enjoyed it.
# 7755  My grandmother made this and when it came out of the oven she would spread some butter on it then sprinkle cinnamon and sugar on it.
#
#      sentiment_score  recipe_name_length  review_length
# 7761  None           -1.358367            0.104341
# 7757  None           -1.358367            0.048522
# 7759  None           -1.358367            0.069318
# 7758  None           -1.358367            0.074425
# 7755  None           -1.358367            0.047793

# %% [markdown]
# ### 5. Split the data into training and testing

# %%
X = data_ML[['user_reputation', 'created_at', 'reply_count', 'thumbs_up', 
           'thumbs_down', 'stars', 'recipe_name_length', 'review_length']]
y = data_ML[ 'best_score']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 100)

# %% [markdown]
# ## B. Model Development

# %% [markdown]
# ### 1. Linear Regression

# %%
# initialize Linear Regression object
LR_model = LinearRegression()

# fit the model
LR_model.fit(X_train, y_train)

# predict
LR_predictions = LR_model.predict(X_test)

# get coefficients of model
LR_params = []
for c in LR_model.coef_: LR_params.append("{:.4f}".format(c))

# %% [markdown]
# ### 2. Ridge Regression

# %%
# initialize parameter grid for CV
RR_param_grid = {'alpha': [0.01, 0.1, 1, 10]}

# intialize Ridge Regression object
ridge = Ridge()
RR_grid_search = GridSearchCV(estimator=ridge, param_grid = RR_param_grid, cv = 5)

# fit the model with hyperparmater tuning & find best model
RR_grid_search.fit(X_train, y_train)
RR_best_model = RR_grid_search.best_estimator_

# predict using the best model
RR_predictions = RR_best_model.predict(X_test)

# get coefficients of best model
RR_params = []
for c in RR_best_model.coef_: RR_params.append("{:.4f}".format(c))

# %% [markdown]
# ### 3. LASSO

# %%
# initialize parameter grid for CV
LS_param_grid = {'alpha': [0.01, 0.1, 1, 10]}

# intialize LASSO object
lasso = Lasso()
LS_grid_search = GridSearchCV(estimator=lasso, param_grid = LS_param_grid, cv = 5)

# fit the model with hyperparameter tuning & find best model
LS_grid_search.fit(X_train, y_train)
LS_best_model = LS_grid_search.best_estimator_

# predict using the best model
LS_predictions = LS_best_model.predict(X_test)

# get coefficients of best model
LS_params = []
for c in LS_best_model.coef_: LS_params.append("{:.4f}".format(c))

# %% [markdown]
# ### 4. Decision Tree

# %%
# initialize parameter grid for CV
DT_param_grid = {
    'max_depth': [2, 4, 6],  # None for no limit
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 5, 10],
    'criterion': ['friedman_mse'] 
}

# initialize Decision Tree object
dt = DecisionTreeRegressor()
DT_grid_search = GridSearchCV(estimator=dt, param_grid=DT_param_grid, cv=5)

# fit the model with hyperparamter tuning & find best model
DT_grid_search.fit(X_train, y_train)
DT_best_model = DT_grid_search.best_estimator_

# predict using the best model
DT_predictions = DT_best_model.predict(X_test)

# get parameters of best model
DT_params = DT_best_model.get_params()

# %% [markdown]
# ### 5. Random Forest

# %%
# intialize parameter grid for CV
RF_param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [2,4,6],
}

# initialize RandomForest object
rf = RandomForestRegressor()
RF_grid_search = GridSearchCV(estimator = rf, param_grid = RF_param_grid, cv = 5)

# fit the model with hyperparameter tuning & find best model
RF_grid_search.fit(X_train, y_train)
RF_best_model = RF_grid_search.best_estimator_

# predict using the best model
RF_predictions = RF_best_model.predict(X_test)

# get parameters of best model
RF_params = RF_best_model.get_params()

# %% [markdown]
# ### 6. Boosted Trees

# %%
# initialize parameter grid for CV
BT_param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.05, 0.1, 0.2],
    'max_depth': [3, 5, 7]
}

# initialize Boosted Tree object
gbr = GradientBoostingRegressor()
BT_grid_search = GridSearchCV(estimator=gbr, param_grid=BT_param_grid, cv=5)

# fit the model with hyperparameter tuning & find best model
BT_grid_search.fit(X_train, y_train)
BT_best_model = BT_grid_search.best_estimator_

# predict using the best model
BT_predictions = BT_best_model.predict(X_test)

# get parameters of best model
BT_params = BT_best_model.get_params()

# %% [markdown]
# ## C. Model Features

# %%
model_fts = {}
params = [LR_params, RR_params, LS_params, DT_params, RF_params, BT_params]
models = ['Linear Regression', 'Ridge Regression', 'LASSO', 'Decision Tree', 'Random Forest', 'Boosted Trees']

for m, model in enumerate(models):
    model_fts[model] = {'parameters': params[m]}
    
model_features = pd.DataFrame(model_fts).transpose()
pd.set_option('display.max_colwidth', 0)
model_features.style.set_properties(**{'parameters': {'width': 100, 'white-space': 'normal'}})
model_features
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     parameters
# Linear Regression  [0.0637, 0.7549, 0.1066, 2.0455, -0.5679, 0.0062, -0.0010, 0.0605]
# Ridge Regression   [0.0627, 0.7553, 0.1060, 2.0333, -0.5560, 0.0063, -0.0010, 0.0610]
# LASSO              [0.0000, 0.0455, 0.0000, 0.0000, 0.0000, -0.0000, 0.0000, 0.0000]
# Decision Tree      {'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'max_depth': 6, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 5, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': None, 'splitter': 'best'}
# Random Forest      {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 6, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 200, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Boosted Trees      {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 3, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 200, 'n_iter_no_change': None, 'random_state': None, 'subsample': 1.0, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}

# %% [markdown]
# ## D. Model Performance

# %%
model_metrics = {}

model = LinearRegression()
model.fit(X_train, y_train)
predictions = model.predict(X_test)


models = ['Linear Regression', 'Ridge Regression', 'LASSO', 'Decision Tree', 'Random Forest', 'Boosted Trees']
predictions = [LR_predictions, RR_predictions, LS_predictions, DT_predictions, RF_predictions, BT_predictions]

for m, model in enumerate(models):
    mae = mean_absolute_error(y_test, predictions[m])
    mse = mean_squared_error(y_test, predictions[m])
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, predictions[m])
    
    model_name = model  # Name for clarity
    model_metrics[model_name] = {'MAE': mae, 'MSE': mse, 'RMSE': rmse, 'R-Squared': r2}

model_performance = pd.DataFrame(model_metrics)
model_performance
# Out:
#            Linear Regression  Ridge Regression     LASSO  Decision Tree  \
# MAE        0.040946           0.041014          0.086708  0.005175
# MSE        0.005389           0.005389          0.021772  0.000519
# RMSE       0.073407           0.073410          0.147555  0.022781
# R-Squared  0.763134           0.763112          0.042940  0.977188
#
#            Random Forest  Boosted Trees
# MAE        0.004195       0.003165
# MSE        0.000369       0.000381
# RMSE       0.019211       0.019507
# R-Squared  0.983776       0.983274

# %% [markdown]
# ## E. Feature Magnitude / Importances

# %%
# define features in each model & models used
features = ['user_reputation', 'created_at', 'reply_count', 'thumbs_up', 'thumbs_down', 'stars', 'best_score', 'recipe_name_length', 'review_length']
linear_models = ['Linear Regression', 'Ridge Regression', 'LASSO']
tree_models = ['Decision Tree', 'Random Forest', 'Boosted Trees']

# get coefficients & features importances for models
linear_coeff = [LR_model.coef_, RR_best_model.coef_, LS_best_model.coef_]
tree_coeff = [DT_best_model.feature_importances_, RF_best_model.feature_importances_, BT_best_model.feature_importances_]

# initialize coefficient dictionary
model_coeff = {}

for m, model in enumerate(linear_models):
    
    model_coeff[model] = {'user_reputation': linear_coeff[m][0],
                               'created_at': linear_coeff[m][1],
                               'reply_count': linear_coeff[m][2],
                               'thumbs_up': linear_coeff[m][3],
                               'thumbs_down': linear_coeff[m][4],
                               'stars': linear_coeff[m][5],
                               'recipe_name_length': linear_coeff[m][6],
                               'review_length': linear_coeff[m][7],
                              }

for m, model in enumerate(tree_models):
    model_coeff[model] = {'user_reputation': tree_coeff[m][0],
                               'created_at': tree_coeff[m][1],
                               'reply_count': tree_coeff[m][2],
                               'thumbs_up': tree_coeff[m][3],
                               'thumbs_down': tree_coeff[m][4],
                               'stars': tree_coeff[m][5],
                               'recipe_name_length': tree_coeff[m][6],
                               'review_length': tree_coeff[m][7],
                            }
        
model_values = pd.DataFrame(model_coeff)
model_values
# Out:
#                     Linear Regression  Ridge Regression     LASSO  \
# user_reputation     0.063692           0.062671          0.000000
# created_at          0.754922           0.755303          0.045485
# reply_count         0.106618           0.106003          0.000000
# thumbs_up           2.045526           2.033349          0.000000
# thumbs_down        -0.567916          -0.555953          0.000000
# stars               0.006238           0.006306         -0.000000
# recipe_name_length -0.001031          -0.001026          0.000000
# review_length       0.060469           0.061004          0.000000
#
#                     Decision Tree  Random Forest  Boosted Trees
# user_reputation     0.000196       0.001166       0.002093
# created_at          0.749502       0.745799       0.721594
# reply_count         0.000000       0.000227       0.000007
# thumbs_up           0.220402       0.220879       0.244377
# thumbs_down         0.023407       0.025567       0.026780
# stars               0.001504       0.001288       0.001727
# recipe_name_length  0.000000       0.000963       0.000356
# review_length       0.004989       0.004111       0.003067
